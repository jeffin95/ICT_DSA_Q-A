# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_excel(r"C:\Users\jeffi\Downloads\Dataset_w6.xlsx")
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# ...

# %% [markdown]
# # 1. Find out how many countries are there in the dataset.

# %%
print('No. of countries in the list :', dt['country'].count())
# Out:
# No. of countries in the list : 196

# %% [markdown]
# # 2. Examine the data by using visualizations

# %%
fig=plt.subplots(figsize=(14,5))
plt.title('Region VS GDP')
plt.xticks(rotation=90)
sns.boxplot(x=data['Region'],y=data['GDP per capita (current US$)'],data=data)
# Out:
# <AxesSubplot:title={'center':'Region VS GDP'}, xlabel='Region', ylabel='GDP per capita (current US$)'>

# %%
fig=plt.subplots(figsize=(14,5))
plt.title('Region Vs Trade')
plt.xticks(rotation=90)
sns.stripplot(x=data['Region'],y=data['International trade: Imports (million US$)'],data=data)
# Out:
# <AxesSubplot:title={'center':'Region Vs Trade'}, xlabel='Region', ylabel='International trade: Imports (million US$)'>

# %% [markdown]
# # 3.  Find out how many countries with respect to the region are available in the dataset

# %%
data['Region'].value_counts()
# Out:
# WesternAsia          18
# EasternAfrica        17
# Caribbean            16
# WesternAfrica        15
# SouthAmerica         12
# SouthernEurope       12
# South-easternAsia    11
# EasternEurope        10
# NorthernEurope       10
# SouthernAsia          9
# MiddleAfrica          9
# CentralAmerica        8
# WesternEurope         7
# EasternAsia           7
# SouthernAfrica        5
# Polynesia             5
# NorthernAfrica        5
# Melanesia             5
# CentralAsia           5
# NorthernAmerica       4
# Micronesia            4
# Oceania               2
# Name: Region, dtype: int64

# %% [markdown]
# # 4.On average which region has the highest

# %% [markdown]
# a. GDP per capita (current US$)

# %%
highest_gdp=data.groupby('Region')['GDP per capita (current US$)'].mean()
print('The region with highest GDP is: ',highest_gdp.nlargest(1))
fig= plt.subplots(figsize=(10,5))
plt.xticks(rotation=45)
ax=sns.lineplot(data=highest_gdp,markers=True)
ax.set(ylabel='Mean of GDP per capita')
# Out:
# The region with highest GDP is:  Region
# NorthernAmerica    57659.0
# Name: GDP per capita (current US$), dtype: float64
# [Text(0, 0.5, 'Mean of GDP per capita')]

# %% [markdown]
# b. International trade: Imports (million US$)

# %%
highest_trade=data.groupby('Region')['International trade: Imports (million US$)'].mean()
print('The region with highest import trade is: ',highest_trade.nlargest(1))
fig= plt.subplots(figsize=(12,4))
plt.xticks(rotation=90)
ax=sns.lineplot(data=highest_trade,markers=True)
ax.set(ylabel='Mean of International Trade: Imports')
# Out:
# The region with highest import trade is:  Region
# NorthernAmerica    663552.25
# Name: International trade: Imports (million US$), dtype: float64
# [Text(0, 0.5, 'Mean of International Trade: Imports')]

# %% [markdown]
# # 5. Find out which region has more consistent with respect to GDP per capita (currentUS$)

# %%
gdp_variation=data.groupby('Region')['GDP per capita (current US$)'].std().round(3)
gdp_variation.sort_values(ascending=True)
print('The region which is the most consistent with GDP is: ',gdp_variation.nsmallest(1))
fig= plt.subplots(figsize=(12,4))
plt.xticks(rotation=90)
ax=sns.lineplot(data=gdp_variation,markers=True)
ax.set(ylabel='Consistant GDP per Capita')
# Out:
# The region which is the most consistent with GDP is:  Region
# WesternAfrica    815.095
# Name: GDP per capita (current US$), dtype: float64
# [Text(0, 0.5, 'Consistant GDP per Capita')]
